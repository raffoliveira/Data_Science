# %%
import os
import pandas as pd

# %%
#loop in a directory with multiple files
def loop_directory(directory):
  for filename in os.listdir(directory):
    if filename.endswith('.csv'):
      file_directory=os.path.join(directory,filename)
      print(file_directory)
      pd.read_csv(file_directory)

if __name__=='__main__':
  loop_directory('data/')

# %%
#save different models in a specific directory

model
  model1
    NaiveBayes
    XGBoost
      version_1
      version_2
  model2
    NaiveBayes
    XGBoost
      version_1
      version_2
  

import joblib
import os

def create_path_if_not_exists(datapath):
  if not os.path.exists(datapath):
    os.makedirs(datapath)

if __name__=='__main__':

  model_path = 'model/model2/XGBoost/version_2'
  create_path_if_not_exists(model_path)

  joblib.dump(model, model_path) #save file

# %%
#run different models in a specific directory

model
  model1
    NaiveBayes
    XGBoost
      version_1
      version_2
  model2
    NaiveBayes
    XGBoost
      version_1
      version_2
  

import joblib
import os

def create_path_if_not_exists(datapath):
  if not os.path.exists(datapath):
    os.makedirs(datapath)

if __name__=='__main__':

  # df = pd.read(...)

  model_path = 'model/model2/XGBoost/version_2'
  create_path_if_not_exists(model_path)

  model = joblib.load(model_path) #load file
  model.predict(df)

# %%
# run multiple files using arguments parse in command line

import sys
import joblib

#df = pd.read(...)

model_type=sys.argv[1]
model_version=sys.argv[2]
model_path=f'model/model2/{model_type}/version_{model_version}'
print('Loading model from', model_path, 'for training')
model = joblib.load(model_path) #load file
model.predict(df)

#TERMINAL
# >>>python train.py XGBoost 1

# $ for version in 2 3 4
# > do
# > python train.py XGBoost $version
# > done
